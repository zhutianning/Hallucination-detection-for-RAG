# %%
# !unzip -n datas/财报数据库.zip -d datas/ # 解压财报数据库

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Error parsing dependencies of gym: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     opencv-python (>=3.) ; extra == 'all'
#                   ~~~~^
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)

# %%
# !python fitz_pipeline_all.py # 使用fitz_pipeline_all.py处理pdf文件
# Out:
# 找到 26 个 PDF 文件，开始处理...
#   - 正在处理: 2023-03-25-601319.SH-中国人保-601319中国人保2022年年度报告.pdf
#   - 正在处理: 2024-03-20-601126.SH-四方股份-601126四方股份2023年年度报告.pdf
#   - 正在处理: 2024-03-23-601088.SH-中国神华-601088中国神华2023年度报告.pdf
#   - 正在处理: 2024-03-27-600030.SH-中信证券-600030中信证券股份有限公司2023年年度报告.pdf
#   - 正在处理: 2024-03-27-600970.SH-中材国际-600970中国中材国际工程股份有限公司2023年年度报告.pdf
#   - 正在处理: 2024-03-27-601319.SH-中国人保-601319中国人保2023年年度报告.pdf
#   - 正在处理: 2024-03-28-601398.SH-工商银行-601398工商银行2023年度报告.pdf
#   - 正在处理: 2024-03-28-601888.SH-中国中免-601888中国旅游集团中免股份有限公司2023年年度报告.pdf
#   - 正在处理: 2024-03-29-601939.SH-建设银行-601939建设银行2023年年度报告.pdf
#   - 正在处理: 2024-03-29-601988.SH-中国银行-601988中国银行股份有限公司2023年年度报告.pdf
#   - 正在处理: 2024-03-29-601995.SH-中金公司-601995中金公司2023年年度报告.pdf
#   - 正在处理: 2024-04-29-600916.SH-中国黄金-600916中国黄金集团黄金珠宝股份有限公司2023年年度报告.pdf
#   - 正在处理: 2024-04-30-688256.SH-寒武纪-6882562023年年度报告.pdf
#   - 正在处理: 2025-03-22-601088.SH-中国神华-601088中国神华2024年度报告.pdf
#   - 正在处理: 2025-03-26-600970.SH-中材国际-中国中材国际工程股份有限公司2024年年度报告.pdf
# ...

# %% [markdown]
# ### 为什么这么做（MinerU 的优势)

# %%
# running under GPU environment
"""
MinerU 可以对PDF进行深度的版面分析，除了能更精准地提取文本块外，还具备以下功能：
识别表格:将表格转化为结构化的Markdown或JSON格式。
提取图片:对文档中的图片进行识别。
图片描述:（可选）调用多模态模型为提取出的图片生成文字说明。
效果:这会为后续的RAG流程提供包含表格和图片信息的、更丰富且更精确的上下文，是解决多模态问题的关键举措。
"""
# !python -u mineru_pipeline_all.py # 使用mineru_pipeline_all.py处理pdf文件
# Out:
# 2025-10-26 23:29:52.517988: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 23:30:03.707325: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 23:30:20.184 | WARNING  | mineru.backend.vlm.predictor:<module>:35 - sglang is not installed. If you are not using sglang, you can ignore this warning.
#
# Step 1: Parsing PDFs:   0%|          | 0/26 [00:00<?, ?pdf/s]2025-10-26 23:31:05.315 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:124 - Batch 1/1: 256 pages/256 pages
# ...

# %% [markdown]
# ## 合并两路抽取结果

# %%
#最终产物：all_pdf_page_chunks_merged.json。
# !python merge_chunks.py
# Out:
# 合并后 chunks: 32377 | 平均长度: 689.6 | 中位: 768

# %%
# !python rag_from_page_chunks_original.py # 使用rag_from_page_chunks_original.py处理pdf文件

# %%
# !python -u rag_from_page_chunks_rerank.py # 运行重排策略
